# %% [markdown]
# Instructions to run these various models aswell as over all tips up to tutorial 4(single model). Links to the straight Julia files are in the repo under their respective names.

# %% [markdown]
# To run any model call call mimi and then the model. After this set the model to a variable using modelname.get_model() notation then run it by using the run function.
# Example below.

# %%
#initiates the models you are using
using Mimi
using MimiFUND


#runs FUND model
m = MimiFUND.get_model()
run(m)

# %% [markdown]
# Below are the different viewing forms of the data. Running the standard cell should result in a dataframe with 16 rows for the year 1950. Comment out the last row of the code by adding a # before the getdataframe call to get the full data frame. It should start with 1950-USA-1643.9 and end with 3000-SIS-4.08653e5

# %%
# Take a lot at results
m[:socioeconomic, :income] # complete array
m[:socioeconomic, :income][100] # individual index
getdataframe(m, :socioeconomic=>:income) # dataframe requesting one variable from one component
getdataframe(m, :socioeconomic=>:income)[1:16,:]# results for regions in 1950
# Out:
# 16×3 DataFrame
#  Row │ time   regions  income
#      │ Int64  String   Float64?
# ─────┼────────────────────────────
#    1 │  1950  USA      1643.9
#    2 │  1950  CAN        84.8225
#    3 │  1950  WEU      1913.32
#    4 │  1950  JPK       616.022
#    5 │  1950  ANZ       119.058
#    6 │  1950  EEU        87.9192
#    7 │  1950  FSU       167.309
#    8 │  1950  MDE        76.065
#    9 │  1950  CAM        40.5139
#   10 │  1950  LAM       193.139
#   11 │  1950  SAS        57.9714
#   12 │  1950  SEA        25.6943
#   13 │  1950  CHI        18.8014
#   14 │  1950  MAF        13.4482
#   15 │  1950  SSA        94.686
#   16 │  1950  SIS         6.82114

# %% [markdown]
# Below is is one way would view the data. When the window opens select the component biodiverity and the variable nospecies. The resulting graph should look like the image below.

# %%
# Explore Plots and Graphs
explore(m) #creates second window with graphs

# %% [markdown]
# ![image.png](attachment:image.png)
